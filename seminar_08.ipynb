# %% [markdown]
# <a href="https://colab.research.google.com/github/Yulia74/Python_seminars/blob/main/seminar_08.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %% [markdown]
# Задача №57.
# 1. Прочесть с помощью pandas файл california_housing_test.csv, который находится в папке sample_data

# %%
df = pd.read_csv('sample_data/california_housing_train.csv') # в скобках путь к файлу ('sample_data/california_housing_test.csv')

# %% [markdown]
# 2. Посмотреть сколько в нем строк и столбцов

# %%
df.shape # возвращает кортеж из количества строк и столбцов
# Out:
# (17000, 9)

# %% [markdown]
# 3. Определить какой тип данных имеют столбцы

# %%
df.dtypes # узнать тип данных в столбцах
# Out:
# longitude             float64
# latitude              float64
# housing_median_age    float64
# total_rooms           float64
# total_bedrooms        float64
# population            float64
# households            float64
# median_income         float64
# median_house_value    float64
# dtype: object

# %% [markdown]
# Задача №59.
# 1. Проверить есть ли в файле пустые значения

# %%
df.isnull() # обнаружить пустые значения в таблице (True-пустая ячейка, False-заполенная)
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0          False     False               False        False           False
# 1          False     False               False        False           False
# 2          False     False               False        False           False
# 3          False     False               False        False           False
# 4          False     False               False        False           False
# ...          ...       ...                 ...          ...             ...
# 16995      False     False               False        False           False
# 16996      False     False               False        False           False
# 16997      False     False               False        False           False
# 16998      False     False               False        False           False
# 16999      False     False               False        False           False
#
# ...

# %%
df.isnull().sum() # выводит количество null-значений в каждой ячейке по столбцам
# Out:
# longitude             0
# latitude              0
# housing_median_age    0
# total_rooms           0
# total_bedrooms        0
# population            0
# households            0
# median_income         0
# median_house_value    0
# dtype: int64

# %% [markdown]
# 2. Показать median_house_value где median_income < 2

# %%
df[df.median_income < 2] ['median_house_value']
# Out:
# 0        66900.0
# 1        80100.0
# 2        85700.0
# 4        65500.0
# 7        48500.0
#           ...
# 16984    70000.0
# 16989    58100.0
# 16990    78300.0
# 16994    76100.0
# 16998    85800.0
# Name: median_house_value, Length: 2005, dtype: float64

# %% [markdown]
# 3. Показать данные в первых 2 столбцах

# %%
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
# 3    -114.57     33.64                14.0       1501.0           337.0
# 4    -114.57     33.57                20.0       1454.0           326.0
#
#    population  households  median_income  median_house_value
# 0      1015.0       472.0         1.4936             66900.0
# 1      1129.0       463.0         1.8200             80100.0
# 2       333.0       117.0         1.6509             85700.0
# 3       515.0       226.0         3.1917             73400.0
# 4       624.0       262.0         1.9250             65500.0

# %%
df[['longitude', 'latitude']]
# Out:
#        longitude  latitude
# 0        -114.31     34.19
# 1        -114.47     34.40
# 2        -114.56     33.69
# 3        -114.57     33.64
# 4        -114.57     33.57
# ...          ...       ...
# 16995    -124.26     40.58
# 16996    -124.27     40.69
# 16997    -124.30     41.84
# 16998    -124.30     41.80
# 16999    -124.35     40.54
#
# [17000 rows x 2 columns]

# %%
for i in df.columns[:2]:         # аналогия для предыдущей строки
    print(df[i])
# Out:
# 0       -114.31
# 1       -114.47
# 2       -114.56
# 3       -114.57
# 4       -114.57
#           ...
# 16995   -124.26
# 16996   -124.27
# 16997   -124.30
# 16998   -124.30
# 16999   -124.35
# Name: longitude, Length: 17000, dtype: float64
# 0        34.19
# 1        34.40
# 2        33.69
# 3        33.64
# 4        33.57
#          ...
# 16995    40.58
# 16996    40.69
# 16997    41.84
# 16998    41.80
# 16999    40.54
# Name: latitude, Length: 17000, dtype: float64

# %% [markdown]
# 3. Выбрать данные где housing_median_age < 20 и median_house_value > 70000

# %%
df[(df['housing_median_age'] < 20) & (df['median_house_value'] > 70000)]
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 1        -114.47     34.40                19.0       7650.0          1901.0
# 2        -114.56     33.69                17.0        720.0           174.0
# 3        -114.57     33.64                14.0       1501.0           337.0
# 10       -114.60     33.62                16.0       3741.0           801.0
# 23       -114.98     33.82                15.0        644.0           129.0
# ...          ...       ...                 ...          ...             ...
# 16976    -124.17     40.75                13.0       2171.0           339.0
# 16983    -124.19     41.78                15.0       3140.0           714.0
# 16991    -124.23     41.75                11.0       3159.0           616.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
#
# ...

# %%
df.query('housing_median_age < 20 and median_house_value > 70000')  # тоже самое, только проще запись
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 1        -114.47     34.40                19.0       7650.0          1901.0
# 2        -114.56     33.69                17.0        720.0           174.0
# 3        -114.57     33.64                14.0       1501.0           337.0
# 10       -114.60     33.62                16.0       3741.0           801.0
# 23       -114.98     33.82                15.0        644.0           129.0
# ...          ...       ...                 ...          ...             ...
# 16976    -124.17     40.75                13.0       2171.0           339.0
# 16983    -124.19     41.78                15.0       3140.0           714.0
# 16991    -124.23     41.75                11.0       3159.0           616.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
#
# ...

# %% [markdown]
# Задача №61.
# 1. Определить какое максимальное и минимальное значение median_house_value

# %%
print(df['median_house_value'].max())
# Out:
# 500001.0

# %%
df['median_house_value'].min()     # можно без print
# Out:
# 14999.0

# %% [markdown]
# 2. Показать максимальное median_house_value, где
# median_income = 3.1250

# %%
df[df.median_income == 3.1250] ['median_house_value'].max()
# Out:
# 380400.0

# %% [markdown]
# 3. Узнать какая максимальная population в зоне
# минимального значения median_house_value

# %%
df[df.median_house_value == df['median_house_value'].min()] # вначале выбираем минимальные знаения, а затем
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 568      -117.02     36.40                19.0        619.0           239.0
# 3226     -117.86     34.24                52.0        803.0           267.0
# 16643    -122.74     39.71                16.0        255.0            73.0
# 16801    -123.17     40.31                36.0         98.0            28.0
#
#        population  households  median_income  median_house_value
# 568         490.0       164.0         2.1000             14999.0
# 3226        628.0       225.0         4.1932             14999.0
# 16643        85.0        38.0         1.6607             14999.0
# 16801        18.0         8.0         0.5360             14999.0

# %%
df[df.median_house_value == df['median_house_value'].min()] ['population'].max()
# Out:
# 628.0
